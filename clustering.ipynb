# %% [markdown]
# <a href="https://colab.research.google.com/github/yashraj-02-techie/mldls/blob/main/clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Mall_Customers.csv', usecols=['Age','Annual Income (k$)','Spending Score (1-100)'])
print(dataset)
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
X = dataset.iloc[:,:].values
X1 = dataset.iloc[:,0].values
X2 = dataset.iloc[:,1].values

plt.scatter(X1,X2)
plt.plot()
# Out:
# []

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3)

labels = kmeans.fit_predict(dataset)
dataset["KMeans"]= labels

centroids = kmeans.cluster_centers_
print("Centroid values")
print(centroids)
# Out:
# Centroid values
# [[ 3.26923077e+01  8.65384615e+01  8.21282051e+01  1.00000000e+00]
#  [ 4.03947368e+01  8.70000000e+01  1.86315789e+01 -2.22044605e-16]
#  [ 4.03252033e+01  4.41544715e+01  4.98292683e+01  3.73983740e-01]]

# %%
print(dataset)
len(X)
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)  KMeans
# 0     19                  15                      39       2
# 1     21                  15                      81       2
# 2     20                  16                       6       2
# 3     23                  16                      77       2
# 4     31                  17                      40       2
# ..   ...                 ...                     ...     ...
# 195   35                 120                      79       0
# 196   45                 126                      28       1
# 197   32                 126                      74       0
# 198   32                 137                      18       1
# 199   30                 137                      83       0
#
# [200 rows x 4 columns]
# 200

# %%
k = 3

colors = ['r', 'g', 'b']
fig, ax = plt.subplots()
for i in range(k):
        points = np.array([X[j] for j in range(len(X)) if labels[j] == i])
        ax.scatter(points[:, 0], points[:, 1], c=colors[i])
      
ax.scatter(centroids[:, 0], centroids[:, 1], marker='*', s=500)
