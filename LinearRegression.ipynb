# %% [markdown]
# <a href="https://colab.research.google.com/github/yashraj-02-techie/mldls/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('winequality-red.csv', sep=';' , usecols=['alcohol','quality'])
display(dataset)
# Out:
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 2 columns]

# %%
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values

print(X)
print(Y)
# Out:
# [[ 9.4]
#  [ 9.8]
#  [ 9.8]
#  ...
#  [11. ]
#  [10.2]
#  [11. ]]
# [5 5 5 ... 6 5 6]

# %%
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title('Alcohol vs. Quality')
plt.scatter(X,Y,color='red',marker='+')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.4)
print(X_train.shape, X_test.shape)
# Out:
# (959, 1) (640, 1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
print(Y_pred)
print(Y_train)
# Out:
# [5.12392921 5.39560787 6.14272419 5.25976854 5.66728653 5.80312586
#  5.8370857  5.80312586 5.39560787 5.87104553 5.25976854 6.07480453
#  5.25976854 5.29372837 5.46352754 5.39560787 5.49748737 6.14272419
#  6.10876436 5.90500536 5.29372837 5.93896519 5.36164804 5.19184887
#  5.12392921 6.44836268 5.25976854 5.19184887 5.76916603 5.90500536
#  5.39560787 5.59936687 5.22580871 5.25976854 5.46352754 6.65212168
#  5.56540703 5.32768821 6.17668402 5.29372837 6.24460369 5.80312586
#  5.5314472  5.5314472  5.36164804 6.04084469 5.76916603 5.22580871
#  6.31252335 5.56540703 5.22580871 5.6333267  5.90500536 5.7352062
#  5.7352062  5.32768821 6.31252335 6.48232252 6.27856352 5.76916603
#  5.56540703 5.22580871 5.80312586 5.70124637 5.25976854 5.32768821
#  5.46352754 5.49748737 5.7352062  5.59936687 5.5314472  5.22580871
#  5.56540703 5.12392921 5.29372837 6.04084469 5.49748737 5.80312586
#  5.29372837 5.6333267  5.5314472  5.29372837 5.90500536 5.22580871
# ...

# %%
accuracy = model.score(X_test,Y_test)
print(accuracy)
# Out:
# 0.24256292437351945

# %%
plt.scatter(X_train,Y_train,color='blue',marker='+')
plt.xlabel('Alcohol')
plt.ylabel('Quality')
plt.title('Alcohol vs Quality (Train set)')
plt.plot(X_train, model.predict(X_train), color='red')
plt.show()

plt.scatter(X_test,Y_test,color='blue',marker='+')
plt.xlabel('area')
plt.ylabel('price')
plt.title('Area vs. Price (Test Set)')
plt.plot(X_test, model.predict(X_test), color='red')
plt.show()

# %%
test_data = np.array([[9]])
test_pred = model.predict(test_data)
print(test_pred)
# Out:
# [5.12392921]

# %%
AlcoholAmount = float(input("Enter the amount of alcohol that you think is in your drink?"))
QualityOfWine = model.predict(np.array([[AlcoholAmount]])) 
print('Estimated Quality of wine with ' + str(AlcoholAmount) + ' amount of alcohol is ' + str(QualityOfWine[0]))
# Out:
# Estimated Quality of wine with 13.0 amount of alcohol is 6.482322517525888
